# %% [markdown]
# <img style="position: absolute;right: 0;" src="data:image/svg+xml,%3Csvg%20height%3D%2295.834%22%20width%3D%2289.004%22%20xml%3Aspace%3D%22preserve%22%20xmlns%3D%22http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg%22%3E%3Cpath%20style%3D%22fill%3A%230092bd%3Bfill-opacity%3A1%3Bfill-rule%3Anonzero%3Bstroke%3Anone%3Bstroke-width%3A.721541%22%20d%3D%22m39.987%200%204.506%2056.336L48.986%200ZM0%2041.473c7.22%205.11%2030.7%2021.33%2030.7%2021.33L0%2032.02Zm0-11.61%2032.69%2031.06L0%2016.767ZM29.056%200l12.985%2056.536L38.711%200Zm10.6%2057.1L27.769%200H6.177c-3.4%200-6.17%202.9-6.17%206.475v8.1l34.915%2044.747L6.458%206.202c.354-.212.688-.426%201.038-.637l29.558%2052.46L16.56%201.037c.359-.153.73-.314%201.1-.46zM0%2071.853c.422.088%201.091.171%202.013.171l24.83.066C19.369%2070.775%202.508%2068.863%200%2068.42Zm0-5.447c3.731.656%2027.2%203.62%2027.2%203.62S4.3%2062.468%200%2061.001zm0-15.54c6.295%203.108%2029.304%2014.059%2029.304%2014.059S6.777%2048.527%200%2043.546zm0%208.139c3.968%201.254%2028.244%208.561%2028.244%208.561S6.312%2056.218%200%2052.914zm86.24%2013.332c1.567%200%202.415-.237%202.764-.4V68.42c-2.588.466-19.182%202.52-26.645%203.854zM82.824%200h-21.59L49.692%2056.966%2071.312.573c.006%200%20.012.01.016.015l.008-.015c.37.146.749.312%201.123.463l-20.155%2057.21%2029.174-52.68c.005.013.009.013.017.018l.013-.018c.34.219.68.425%201.04.636l-27.79%2053.337%2034.245-44.987V6.473C89.003%202.897%2086.226%200%2082.824%200m-26.14%2061.16%2032.318-31.326V16.772Zm32.319-19.705V32.02l-30.64%2031.05c1.523-1.081%2023.69-16.692%2030.64-21.615M50.294%200l-3.01%2056.388L60.234%200Zm38.709%2066.406v-5.41c-4.247%201.447-26.813%208.905-27.178%209.026.87-.129%2023.62-2.998%2027.178-3.616m0-15.558v-7.302c-6.614%204.845-28.127%2020.823-29.264%2021.673%201.365-.679%2023.203-11.375%2029.264-14.37m0%208.149v-6.084c-6.209%203.252-27.195%2014.27-27.9%2014.64%201.215-.383%2024.118-7.365%2027.9-8.556%22%2F%3E%3Cpath%20style%3D%22fill%3A%2380ba27%3Bfill-opacity%3A1%3Bfill-rule%3Anonzero%3Bstroke%3Anone%3Bstroke-width%3A.721541%22%20d%3D%22M88.544%2074.062c-.455.13-1.204.249-2.304.249l-41.284.015L.87%2074.192a6.236%206.236%200%200%201-.842-.118v5.553c0%204.546%203.081%206.827%207.855%208.234%200%200%2032.092%207.973%2037.04%207.973%204.968%200%2036.218-7.973%2036.218-7.973%204.121-1.236%207.863-3.688%207.863-8.234v-5.718c-.106.047-.254.1-.46.153%22%2F%3E%3C%2Fsvg%3E" alt="UVSQ Logo"/>
# <h1><center>IN202 – Représentation des données</center></h1>
# <h2><center>TD 4 – Manipulation d'images</center></h2>

# %% [markdown]
# On va dans ce TD manipuler des images. Quel format de stockage utilise-t-on pour stocker un pixel ? Et du coup, une image&nbsp;?
#
# <em>À COMPLÉTER</em>
#
# Donc, avant de se lancer directement dans la manipulation de telles données, on va s'entrainer sur des matrices simples.
#
# ## 1. Matrices
#
# Commençons par les imports.

# %%
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import numpy as np
#
# ModuleNotFoundError: No module named 'numpy'

# %% [markdown]
# Créez une matrice avec 3 lignes et 4 colonnes. Définissez la matrice comme une liste de listes Python sans utiliser de boucles.

# %%
mat_liste = #À COMPLÉTER

# %% [markdown]
# Si on veut utiliser NumPy pour manipuler nos matrices, il va falloir convertir cette liste en une structure `numpy array`. Rien de plus simple&nbsp;:

# %%
#définir la matrice comme un numpy array à deux dimensions
mat_numpy = np.array(mat_liste)

# %% [markdown]
# Affichez maintenant le nombre de lignes et de colonnes de `mat_liste` et de `mat_numpy`.

# %%
print("mat_liste, Nombre de lignes:",
      #À COMPLÉTER
      "Nombre de colonnes:",
      #À COMPLÉTER

print("mat_numpy, Nombre de lignes:",
      #À COMPLÉTER
      "Nombre de colonnes:",
      #À COMPLÉTER

# %% [markdown]
# Les valeurs sont les mêmes (heureusement...).
#
# Remplissez `mat_numpy` de valeur 9 en utilisant deux boucles imbriquées sur les index de la matrice.

# %%
def rempli9(matrice):
    #À COMPLÉTER

rempli9(mat_numpy)
print(mat_numpy)

# %% [markdown]
# Maintenant, remplissez la matrice de 8, mais cette fois en utilisant [les fonctions spécifiques de numpy](https://numpy.org/doc/2.1/reference/generated/numpy.ndarray.html), sans faire de boucle.

# %%
def rempli8(matrice):
    #À COMPLÉTER

rempli8(mat_numpy)
print(mat_numpy)

# %% [markdown]
# Créez une liste de taille 50 qui ne contient que des 3, en utilisant une compréhension de liste. Créez ensuite une matrice comme une liste de listes dont la première ligne contient des 1, la deuxième des 2 etc.
#
# Il y a plusieurs manières de faire, la compréhension n'étant pas la plus efficace (cherchez dans la doc NumPy).

# %%
mat = np.array( #À COMPLÉTER

print(mat)

mat = np.array( #À COMPLÉTER

print(mat)

# %% [markdown]
# Dernier exercice sur des matrices, créez la matrice identité de taille 50. Essayez de trouver les 3 manières de faire&nbsp;:
# * avec une double boucle (facile, pas performant)
# * avec une double compréhension (moins facile, très bon exercice, mais pas forcément performant dans le cas de NumPy)
# * avec une fonction adaptée de NumPy

# %%
n = 50

identite = #À COMPLÉTER

print(identite)

# %% [markdown]
# Bien, on arrive sans trop de problème à manipuler des `numpy array` à 2 dimensions. On va pouvoir passer aux images&nbsp;!
#
# ## 2. Matrices de Pixels
#
# On va importer la librairie PIL pour charger et afficher des images. On importe aussi TkInter, mais uniquement pour l'interface d'ouverture de fichier (pour cette séance...).

# %%
from PIL import Image

# %% [markdown]
# On va implémenter deux fonctions qui vont nous simplifier la vie&nbsp;:
# * La fonction <code class="language-python"><span class="ͼv">charger</span></code> renvoie la matrice représentant l'image stockée dans le fichier nommé `nom_fichier`.
# * La fonction <code class="language-python"><span class="ͼv">sauver</span></code> permet de stocker la matrice de pixels passée en paramètre dans un fichier de nom `nom_fichier`.

# %%
def sauver(matPix, nom_fichier):
    Image.fromarray(matPix).save(nom_fichier)

def charger(nom_fichier):
    return np.array(Image.open(nom_fichier))

# %% [markdown]
# Créez une matrice de pixels de taille 100$\times$100 ainsi qu'une fonction qui définit les pixels de la moitié gauche de l'image en vert, et les pixels de moitié droite en bleu. Vous pouvez&nbsp;:
#  * utiliser une double boucle imbriquée
#  * utiliser le slicing
#  * utiliser l'[affectation conditionnelle](https://www.nickmccullum.com/advanced-python/numpy-indexing-assignment/#conditional-selection-using-numpy-arrays) en générant les indices avec la fonction [`np.indices`](https://numpy.org/doc/stable/reference/generated/numpy.indices.html)
#
# Pour visualiser l'image obtenue, vous utiliserez la fonction <code class="language-python"><span class="ͼv">save</span></code> et vous ouvrirez le fichier ainsi généré.

# %%
def remplit_vert_bleu(matrice):
    #À COMPLÉTER

matVB = np.empty((100, 100, 3), dtype=np.uint8)
remplit_vert_bleu(matVB)
sauver(matVB, "vertbleu.png")

# %% [markdown]
# En vous servant de la fonction <code class="language-python"><span class="ͼv">charger</span></code>, calculez le nombre de pixels dans une image `.bmp` de votre choix, puis calculez la taille de l'image en octets. Comparez avec la taille donnée par votre machine.

# %%
matrice = charger("test.bmp")
print(
    #À COMPLÉTER

# %% [markdown]
# Modifiez l'image que vous avez créé précédemment en ajoutant un rectangle noir au milieu de l'image, qui occupera 1/3 de l'espace. Là aussi, vous pouvez utiliser une double boucle ou le slicing.
#
# Pour rappel, si vous voulez diviser deux entiers et ne récupérer que la partie entière du résultat, vous pouvez utiliser l'instruction <span class="ͼ10">//</span>.

# %%
matrice = charger("vertbleu.png")

def ajouteCarreNoir(mat):
    nblig = mat.shape[0]
    nbcol = mat.shape[1]
    #À COMPLÉTER

ajouteCarreNoir(matrice)
sauver(matrice,"vertbleumodif.png")

# %% [markdown]
# De la même manière, ajoutez un filtre qui ne conserve que la composante verte d'une image (une fois encore, double boucle ou slicing, au choix... mais si vous ne l'avez jamais fait, tentez le slicing !).
#
# Pour le slicing, sachez que les numpy array permettent de spécifier certains indices de dimensions explicitement. Par exemple, <code class="language-python">tableau<span class="ͼ14">[[</span><span class="ͼu">3</span><span class="ͼ19">,</span><span class="ͼu">5</span><span class="ͼ19">,</span><span class="ͼu">7</span><span class="ͼ14">]]</span> <span class="ͼ10">=</span> <span class="ͼu">1</span></code> met la valeur `1` aux indices `3`, `5`, et `7` de l'array (notez qu'au lieu d'un indice, on a passé une _liste_ d'indices, c'est une notation spécifique aux numpy array, ça ne marche pas sur les conteneurs standards Python).

# %%
matrice = charger("cheetah.png")

def filtre_vert(mat):
    #À COMPLÉTER

filtre_vert(matrice)
sauver(matrice, "filtre.png")

# %% [markdown]
# Créez maintenant une méthode qui permet d'afficher le négatif de l'image (on inverse la luminosité). Petit indice &nbsp;: Si une composante était très foncée (par exemple $2$), il faudrait qu'elle devienne très claire ($253$ pour reprendre le même exemple).
#
# Une fois de plus, la double boucle est une solution, mais pas la seule. Les plus à l'aise en Python pourraient être tentés de faire une double compréhension. C'est faisable mais pas recommandé, cette approche créerait une nouvelle matrice au lieu de modifier l'originale, qu'il faudrait donc réaffecter à la variable (ou à une autre). L'approche scalaire, là encore possible, sera nettement plus simple à l'écriture, et beaucoup plus rapide à l'exécution. Dans ce cas, et comme pour la double boucle, pas besoin de faire de <code class="language-python"><span class="ͼs">return</span></code>, il faut juste écraser la variable passée en paramètre (puisque c'est une référence).

# %%
matrice = charger("cheetah.png")

def negatif(mat):   
    #À COMPLÉTER

negatif(matrice)
sauver(matrice,"negatif.png")

# %% [markdown]
# Maintenant, créez une méthode qui permet d'afficher le symétrique de l'image par rapport à la droite verticale en son milieu. Là, on peut de nouveau utiliser 3 approches&nbsp;:
# * La double boucle&nbsp;: il faudra vraisemblablement créer un array vide et le remplir avec les données de la matrice initiale prises dans le sens inverse
# * Le slincing&nbsp;: cette solution est particulièrement astucieuse et élégante. Un indice&nbsp;: ça joue sur le _pas_ du slicing (le troisième argument) et la possibilité de spécifier un pas _négatif_...
# * La double compréhension&nbsp;: utilise la même astuce que le slicing, mais est affublée des mêmes défauts que pour la question précédente.
# * Une fonction spécifique de NumPy (on vous laisse chercher...)
#
# Ici, la version avec slicing est fortement recommandée. D'ailleurs, si vous arrivez à l'implémenter, vous pouvez appliquer le même principe pour faire très simplement une rotation de 180° à l'image.

# %%
matrice = charger("cheetah.png")

def symetrique(mat):   
    #À COMPLÉTER

sauver(symetrique(matrice), "sym.png")

# %% [markdown]
# Maintenant, on va faire varier la clarté de l'image, en lui appliquant un facteur. Par exemple, $1,5$ éclaircira l'image de 50%. Comment faire&nbsp;?
#
# <em>À COMPLÉTER</em>
#
# On va changer de fichier, histoire de voir un peu mieux les effets de notre traitement. Et on va arrêter de sauver à chaque fois le fichier. À partir de maintenant, on va juste afficher la modification appliquée avec Pillow.

# %%
matrice = charger("paysage.jpg")

def clarte(facteur):
    
    #À COMPLÉTER
    
    nouvelle_image = Image.fromarray(nouvelle_matrice)
    return nouvelle_image

facteur = 1.5  # Augmente la luminosité de 50%

resultat = clarte(facteur)
resultat.show()  # Affiche l'image résultante

# %% [markdown]
# Ça a l'air d'aller. Mais on a tout de même perdu certains détails (regardez les nuages, notamment ceux à la base de la montagne dans le fond). À votre avis, pourquoi&nbsp;?
#
# <em>À COMPLÉTER</em>

# %% [markdown]
# ## 3. Traitement avancé d'images
#
# Pour remédier au problème qu'on a eu, on va appliquer la méthode de _correction gamma_. La correction gamma utilise la fonction suivante :
# $$ V_{out} = V_{in}^{\gamma} $$
# avec&nbsp;:
# * $V_{in}$ la valeur d'entrée du pixel
# * $V_{out}$ la valeur de sortie
#  * $\gamma$ le facteur de correction.
#
# Mais attention, ça ne s'applique pas directement sur une matrice de pixels&nbsp;! Réfléchissez, le but est d'éviter le dépassement de capacité de la représentation d'un canal. Ce qui veut dire que, si on applique la correction gamma sur une image en 24 bits, les pixels de sortie devront avoir des valeurs dans $[0, 255]$ comme les valeurs de départ. Si on applique la correction gamma tel quel, ça ne marche pas (parce que la seule valeur de $\gamma$ pour laquelle on ne dépasse pas 255, c'est 1, c'est-à-dire une absence de correction). Pour corriger ce défaut, on va _normaliser_ les valeurs de pixels, c'est-à-dire les ramener à une plage de valeur plus adaptée. À votre avis, quelles sont les valeurs de $V_{in}$ pour lesquelles l'application de la fonction gamma ne provoquent pas de dépassent à droite&nbsp;?
#
# <em>À COMPLÉTER</em>
#
# Grace à ça, on va éviter la saturation numérique &nbsp;! Après transformation, il faudra juste renormaliser ces valeurs au nombre de bits utilisés pour représenter un canal.
#
# Vous noterez que l'ajustement est non linéaire, l'exposant $\gamma$ affecte différemment les valeurs selon leur intensité. Pour les valeurs proches de 0 ou 1, la fonction gamma a un effet moins prononcé&nbsp:
# * Quand $V_{in}$ approche 0 : $V_{out}$ tend aussi vers 0, mais plus lentement.
# * Quand $V_{in}$ approche 1 : $V_{out}$ tend aussi vers 1, mais plus lentement.
#
# Et si vous regarder le comportement de cette fonction, vous verrez que pour $\gamma < 1$, l'effet est plus prononcé sur les valeurs sombres, tandis que pour $\gamma > 1$, l'effet est plus marqué sur les valeurs claires. Tout simplement parce qu'une puissance d'un $\gamma < 1$ revient à faire une racine n-ième. C'est donc particulièrement adapté à l'ajustement de luminosité&nbsp;!
# <center><img width="80%" alt="Gamma_correction" src="data:image/svg+xml,%3Csvg%20xmlns%3D%22http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg%22%20width%3D%221407.93%22%20height%3D%22584.165%22%20viewBox%3D%220%200%201569.626%20613.081%22%20xmlns%3Av%3D%22https%3A%2F%2Fvecta.io%2Fnano%22%3E%3Cstyle%3E%3C!%5BCDATA%5B.B%7Bfill%3A%23000%7D.C%7Btext-anchor%3Amiddle%7D.D%7Btext-anchor%3Aend%7D.E%7Bfont-family%3AArial%7D.F%7Bwriting-mode%3Alr-tb%7D.G%7Bfont-size%3A24px%7D.H%7Bfill%3A%2300f%7D.I%7Bstroke-width%3A1.8%7D.J%7Bstroke%3A%2300f%7D.K%7Bfont-family%3ACambria%20Math%7D.L%7Bstroke-width%3A2.453%7D.M%7Bmarker-end%3Aurl(%23marker33)%7D.N%7Bstroke-dasharray%3A10.8%2C%2010.8%7D.O%7Bfill%3Acontext-stroke%7D.P%7Bfill-rule%3Aevenodd%7D.Q%7Bstroke%3Acontext-stroke%7D.R%7Bmarker-start%3Aurl(%23A)%7D%5D%5D%3E%3C%2Fstyle%3E%3Cdefs%3E%3Cmarker%20id%3D%22A%22%20refX%3D%220%22%20refY%3D%220%22%20orient%3D%22auto-start-reverse%22%20markerWidth%3D%221%22%20markerHeight%3D%221%22%20viewBox%3D%220%200%201%201%22%20overflow%3D%22visible%22%3E%3Cpath%20transform%3D%22scale(.5)%22%20d%3D%22M6%200l-9%205V-5z%22%20stroke-width%3D%221pt%22%20class%3D%22O%20P%20Q%22%2F%3E%3C%2Fmarker%3E%3Cmarker%20id%3D%22B%22%20refX%3D%220%22%20refY%3D%220%22%20orient%3D%22auto-start-reverse%22%20markerWidth%3D%221%22%20markerHeight%3D%221%22%20viewBox%3D%220%200%201%201%22%20overflow%3D%22visible%22%3E%3Cpath%20transform%3D%22scale(.5)%22%20d%3D%22M6%200l-9%205V-5z%22%20stroke-width%3D%221pt%22%20class%3D%22O%20P%20Q%22%2F%3E%3C%2Fmarker%3E%3Cpath%20id%3D%22C%22%20d%3D%22M918.293%20517.597h9m499%200h-9%22%2F%3E%3Cpath%20id%3D%22D%22%20d%3D%22M918.293%20517.597v-9m0-418v9%22%2F%3E%3Cpath%20id%3D%22E%22%20d%3D%22M629.481%20151.342c-4%200-8%202-9%205-2%203-2%208%200%2011%201%203%203%205%206%206%203%200%207%200%209-3h1v3h11v4h6v-4c3%200%205-1%207-3v7h7v-4c2%200%205-1%206-3v3h12v-10l1-1c1-1%201%200%201%201v10h5c0%202%202%204%204%204%203%201%207%201%209-2%202-2%202-5%202-8v-11h-6c-3-1-7%200-8%203-1-3-5-4-7-3h-5l-1-1v-4h-7v7c-1-2-5-3-7-2h-6v2c-2-2-5-3-8-2h-4v-5h-12v3c-2-2-5-3-7-3zm0%206l2%202%201%202%204-1v3l-4-1-2%204c-1%201-4%200-5-2l1-6zm25%205l1%202-1%203-1-2zm14%200l1%202-1%203-2-2c0-1%200-3%202-3zm31%200l1%202-1%202-1-2z%22%2F%3E%3C%2Fdefs%3E%3Cg%20fill%3D%22none%22%3E%3Cg%20stroke%3D%22%23000%22%3E%3Cuse%20href%3D%22%23C%22%2F%3E%3Ctext%20transform%3D%22translate(910.293%20521.597)%22%20class%3D%22B%20D%22%3E0%3C%2Ftext%3E%3Cuse%20href%3D%22%23C%22%20y%3D%22-85%22%2F%3E%3Ctext%20transform%3D%22translate(910.293%20436.597)%22%20class%3D%22B%20D%22%3E0.2%3C%2Ftext%3E%3Cuse%20href%3D%22%23C%22%20y%3D%22-171%22%2F%3E%3Ctext%20transform%3D%22translate(910.293%20350.597)%22%20class%3D%22B%20D%22%3E0.4%3C%2Ftext%3E%3Cuse%20href%3D%22%23C%22%20y%3D%22-256%22%2F%3E%3Ctext%20transform%3D%22translate(910.293%20265.597)%22%20class%3D%22B%20D%22%3E0.6%3C%2Ftext%3E%3Cuse%20href%3D%22%23C%22%20y%3D%22-342%22%2F%3E%3Ctext%20transform%3D%22translate(910.293%20179.597)%22%20class%3D%22B%20D%22%3E0.8%3C%2Ftext%3E%3Cuse%20href%3D%22%23C%22%20y%3D%22-427%22%2F%3E%3Ctext%20transform%3D%22translate(910.293%2094.597)%22%20class%3D%22B%20D%22%3E1%3C%2Ftext%3E%3Cuse%20href%3D%22%23D%22%2F%3E%3Ctext%20transform%3D%22translate(919.293%20539.597)%22%20class%3D%22B%20C%22%3E0%3C%2Ftext%3E%3Cuse%20href%3D%22%23D%22%20x%3D%22102%22%2F%3E%3Ctext%20transform%3D%22translate(1020.293%20539.597)%22%20class%3D%22B%20C%22%3E0.2%3C%2Ftext%3E%3Cuse%20href%3D%22%23D%22%20x%3D%22203%22%2F%3E%3Ctext%20transform%3D%22translate(1121.293%20539.597)%22%20class%3D%22B%20C%22%3E0.4%3C%2Ftext%3E%3Cuse%20href%3D%22%23D%22%20x%3D%22305%22%2F%3E%3Ctext%20transform%3D%22translate(1223.293%20539.597)%22%20class%3D%22B%20C%22%3E0.6%3C%2Ftext%3E%3Cuse%20href%3D%22%23D%22%20x%3D%22406%22%2F%3E%3Ctext%20transform%3D%22translate(1324.293%20539.597)%22%20class%3D%22B%20C%22%3E0.8%3C%2Ftext%3E%3Cuse%20href%3D%22%23D%22%20x%3D%22508%22%2F%3E%3Ctext%20transform%3D%22translate(1426.293%20539.597)%22%20class%3D%22B%20C%22%3E1%3C%2Ftext%3E%3Cpath%20d%3D%22M918.293%2090.597v427h508v-427z%22%2F%3E%3Cpath%20d%3D%22M919.293%20517.597l507-428%22%20class%3D%22I%22%2F%3E%3C%2Fg%3E%3Cpath%20d%3D%22M919.293%20517.597c72%200%20147-2%20213-32%2080-36%20140-105%20186-177%2044-69%2078-143%20108-219%22%20class%3D%22I%20J%22%2F%3E%3Cpath%20d%3D%22M919.293%20517.597c2-38%202-75%205-112%208-51%2035-98%2072-132%2058-53%20131-86%20203-114%2074-28%20150-50%20227-70%22%20stroke%3D%22%23c10000%22%20class%3D%22I%22%2F%3E%3C%2Fg%3E%3Ctext%20x%3D%221146.893%22%20y%3D%22220.605%22%20xml%3Aspace%3D%22preserve%22%20fill%3D%22red%22%20transform%3D%22translate(0%20-10.408)%22%20class%3D%22D%20E%20F%20G%22%3E%3Ctspan%20x%3D%221035.493%22%20y%3D%22220.605%22%3E%3Ctspan%20x%3D%221035.493%22%20y%3D%22220.605%22%20class%3D%22K%22%3E%CE%B3%20%3D%200.3%3C%2Ftspan%3E%3C%2Ftspan%3E%3Ctspan%20x%3D%221035.493%22%20y%3D%22250.605%22%3EPlus%20fonc%C3%A9%3C%2Ftspan%3E%3C%2Ftext%3E%3Ctext%20x%3D%221370.993%22%20y%3D%22574.805%22%20xml%3Aspace%3D%22preserve%22%20class%3D%22B%20E%20F%20G%22%3E%3Ctspan%20x%3D%221370.993%22%20y%3D%22564.397%22%3EIntensit%C3%A9%20de%20d%C3%A9part%3C%2Ftspan%3E%3C%2Ftext%3E%3Ctext%20x%3D%22818.093%22%20y%3D%2278.905%22%20xml%3Aspace%3D%22preserve%22%20class%3D%22B%20E%20F%20G%22%3E%3Ctspan%20x%3D%22818.093%22%20y%3D%2268.497%22%3EIntensit%C3%A9%20corrig%C3%A9e%3C%2Ftspan%3E%3C%2Ftext%3E%3Ctext%20x%3D%221282.993%22%20y%3D%22390.205%22%20xml%3Aspace%3D%22preserve%22%20transform%3D%22translate(0%20-10.408)%22%20class%3D%22B%20E%20F%20G%22%3E%3Ctspan%20x%3D%221282.993%22%20y%3D%22390.205%22%3E%3Ctspan%20x%3D%221282.993%22%20y%3D%22390.205%22%20class%3D%22H%20K%22%3E%CE%B3%20%3D%203%3C%2Ftspan%3E%3C%2Ftspan%3E%3Ctspan%20x%3D%221282.993%22%20y%3D%22420.205%22%20class%3D%22H%22%3EPlus%20clair%3C%2Ftspan%3E%3C%2Ftext%3E%3Cpath%20d%3D%22M1236.293%20241.597l-7%204%204%203v7l-3%201v5h13v-5l-3-1v-15h-4zm-45%204l-6%203%203%204%202-1%201%208v7l4-1%202-1v-5l6-10v-4h-6l-1%203c-1-1-3-3-5-3zm15%204v8h19v-11h-19zm67%2021l-3%202v2h-2c-4-1-8%200-10%203-1-2-4-4-7-3l-4%201c-1-1-3-2-5-1h-14v2c-3-3-9-3-12%200-2-2-6-3-9-2s-4%204-4%207c-1%203%200%206%202%208%204%203%209%203%2011-1l1%201c3%203%209%203%2011%200v2h7v-10h1v10h7v-10h1v1c0%203%201%206%203%208%203%201%206%202%209%200l3-2c1%203%205%204%208%203l4-2%205%202h6l1-1v-1c4%203%209%203%2012-1v3h7v-10l1-1v11h7v-12c0-2-2-4-4-5h-11v2c-3-3-9-3-12%200v-7h-6s0-2-1-1zm-151%201v20h7v-7c3%200%206%200%208-2h1c-2%202-1%206%201%208h8l2%201h7c2%201%206%200%208-3%201-2%202-5%200-7h1l-2-6c-2-1-5-2-8-1l-3%202c-2-2-5-2-7-2l-5%201c-1-2-3-5-5-5l-8-1h-5zm56%200v3c-3-1-7%201-8%204v9c2%203%205%205%208%204h6v-3c3%203%207%204%2010%202%202%200%204-3%204-5l1-2-1-1c0-3-1-6-3-7-4-2-8-2-11%202v-8h-6zm-47%205h2l-1%201h-3v-1zm80%204v4h-2l1-4zm54%200l1%201v3h-2v-4zm-88%200l1%202-1%203-1-2v-3zm46%200l1%203-1%202c-2%200-2-1-2-2s0-3%202-3zm66%200l2%203-2%202-1-2zm-19%202z%22%20fill%3D%22%23fff%22%20class%3D%22C%22%2F%3E%3Ctext%20x%3D%221309.293%22%20y%3D%22269.005%22%20xml%3Aspace%3D%22preserve%22%20transform%3D%22translate(0%20-10.408)%22%20class%3D%22B%20C%20E%20F%20G%22%3E%3Ctspan%20x%3D%221216.593%22%20y%3D%22269.005%22%20class%3D%22K%22%3E%3Ctspan%20x%3D%221216.593%22%20y%3D%22269.005%22%3E%CE%B3%20%3D%201%3C%2Ftspan%3E%3C%2Ftspan%3E%3Ctspan%20x%3D%221216.593%22%20y%3D%22299.005%22%3EPas%20de%20correction%3C%2Ftspan%3E%3C%2Ftext%3E%3Cg%20fill%3D%22none%22%20stroke%3D%22%23000%22%3E%3Cuse%20href%3D%22%23C%22%20x%3D%22-820.293%22%2F%3E%3Ctext%20transform%3D%22translate(90%20521.597)%22%20class%3D%22B%20D%22%3E0%3C%2Ftext%3E%3Cuse%20href%3D%22%23C%22%20x%3D%22-820.293%22%20y%3D%22-85%22%2F%3E%3Ctext%20transform%3D%22translate(90%20436.597)%22%20class%3D%22B%20D%22%3E0.2%3C%2Ftext%3E%3Cuse%20href%3D%22%23C%22%20x%3D%22-820.293%22%20y%3D%22-171%22%2F%3E%3Ctext%20transform%3D%22translate(90%20350.597)%22%20class%3D%22B%20D%22%3E0.4%3C%2Ftext%3E%3Cuse%20href%3D%22%23C%22%20x%3D%22-820.293%22%20y%3D%22-256%22%2F%3E%3Ctext%20transform%3D%22translate(90%20265.597)%22%20class%3D%22B%20D%22%3E0.6%3C%2Ftext%3E%3Cuse%20href%3D%22%23C%22%20x%3D%22-820.293%22%20y%3D%22-342%22%2F%3E%3Ctext%20transform%3D%22translate(90%20179.597)%22%20class%3D%22B%20D%22%3E0.8%3C%2Ftext%3E%3Cuse%20href%3D%22%23C%22%20x%3D%22-820.293%22%20y%3D%22-427%22%2F%3E%3Ctext%20transform%3D%22translate(90%2094.597)%22%20class%3D%22B%20D%22%3E1%3C%2Ftext%3E%3Cuse%20href%3D%22%23D%22%20x%3D%22-820.293%22%2F%3E%3Ctext%20transform%3D%22translate(99%20539.597)%22%20class%3D%22B%20C%22%3E0%3C%2Ftext%3E%3Cuse%20href%3D%22%23D%22%20x%3D%22-718.293%22%2F%3E%3Ctext%20transform%3D%22translate(200%20539.597)%22%20class%3D%22B%20C%22%3E0.2%3C%2Ftext%3E%3Cuse%20href%3D%22%23D%22%20x%3D%22-617.293%22%2F%3E%3Ctext%20transform%3D%22translate(301%20539.597)%22%20class%3D%22B%20C%22%3E0.4%3C%2Ftext%3E%3Cuse%20href%3D%22%23D%22%20x%3D%22-515.293%22%2F%3E%3Ctext%20transform%3D%22translate(403%20539.597)%22%20class%3D%22B%20C%22%3E0.6%3C%2Ftext%3E%3Cuse%20href%3D%22%23D%22%20x%3D%22-414.293%22%2F%3E%3Ctext%20transform%3D%22translate(504%20539.597)%22%20class%3D%22B%20C%22%3E0.8%3C%2Ftext%3E%3Cuse%20href%3D%22%23D%22%20x%3D%22-312.293%22%2F%3E%3Ctext%20transform%3D%22translate(606%20539.597)%22%20class%3D%22B%20C%22%3E1%3C%2Ftext%3E%3Cpath%20d%3D%22M98%2090.597v427h508v-427z%22%2F%3E%3C%2Fg%3E%3Cg%20class%3D%22I%22%3E%3Cpath%20d%3D%22M98.341%20517.098L399%2089.597m0%201h207%22%20fill%3D%22red%22%20stroke%3D%22red%22%2F%3E%3Cpath%20d%3D%22M98.414%20517.169L606.23%20265.985m0%20.811V89.643%22%20class%3D%22H%20J%22%2F%3E%3C%2Fg%3E%3Cpath%20d%3D%22M692.769%20206.82l-74-80%22%20marker-start%3D%22url(%23B)%22%20class%3D%22H%20J%20L%20M%22%2F%3E%3Cpath%20d%3D%22M606.237%20266.036l112.711-56.356%22%20class%3D%22H%20I%20J%20N%22%2F%3E%3Cpath%20d%3D%22M472%203.597l74%2080%22%20fill%3D%22red%22%20stroke%3D%22red%22%20class%3D%22L%20M%20R%22%2F%3E%3Cg%20class%3D%22I%22%3E%3Cpath%20d%3D%22M98.29%20517.282L606%2089.597%22%20fill%3D%22none%22%20stroke%3D%22%23000%22%2F%3E%3Cpath%20d%3D%22M398%2090.597l78-110%22%20fill%3D%22red%22%20stroke%3D%22red%22%20class%3D%22N%22%2F%3E%3C%2Fg%3E%3Ctext%20x%3D%22550.7%22%20y%3D%22574.805%22%20xml%3Aspace%3D%22preserve%22%20class%3D%22B%20E%20F%20G%22%3E%3Ctspan%20x%3D%22550.7%22%20y%3D%22564.397%22%3EIntensit%C3%A9%20de%20d%C3%A9part%3C%2Ftspan%3E%3C%2Ftext%3E%3Ctext%20x%3D%22-2.238%22%20y%3D%2278.905%22%20xml%3Aspace%3D%22preserve%22%20class%3D%22B%20E%20F%20G%22%3E%3Ctspan%20x%3D%22-2.238%22%20y%3D%2268.497%22%3EIntensit%C3%A9%20corrig%C3%A9e%3C%2Ftspan%3E%3C%2Ftext%3E%3Ctext%20x%3D%22538.576%22%20y%3D%22101.103%22%20xml%3Aspace%3D%22preserve%22%20class%3D%22B%20D%20E%20F%20G%22%3E%3Ctspan%20x%3D%22346.076%22%20y%3D%22150.695%22%20fill%3D%22red%22%3EPlus%20fonc%C3%A9%3C%2Ftspan%3E%3C%2Ftext%3E%3Ctext%20x%3D%22393.083%22%20y%3D%22375.925%22%20xml%3Aspace%3D%22preserve%22%20class%3D%22B%20E%20F%20G%22%3E%3Ctspan%20x%3D%22393.083%22%20y%3D%22395.517%22%20class%3D%22H%22%3EPlus%20clair%3C%2Ftspan%3E%3C%2Ftext%3E%3Cpath%20d%3D%22M453%20270.597l-3%202v2h-2c-4-1-8%200-10%203-1-2-4-4-7-3l-4%201c-1-1-3-2-5-1h-14v2c-3-3-9-3-12%200-2-2-6-3-9-2s-4%204-4%207c-1%203%200%206%202%208%204%203%209%203%2011-1l1%201c3%203%209%203%2011%200v2h7v-10h1v10h7v-10h1v1c0%203%201%206%203%208%203%201%206%202%209%200l3-2c1%203%205%204%208%203l4-2%205%202h6l1-1v-1c4%203%209%203%2012-1v3h7v-10l1-1v11h7v-12c0-2-2-4-4-5h-11v2c-3-3-9-3-12%200v-7h-6s0-2-1-1zm-151%201v20h7v-7c3%200%206%200%208-2h1c-2%202-1%206%201%208h8l2%201h7c2%201%206%200%208-3%201-2%202-5%200-7h1l-2-6c-2-1-5-2-8-1l-3%202c-2-2-5-2-7-2l-5%201c-1-2-3-5-5-5l-8-1h-5zm56%200v3c-3-1-7%201-8%204v9c2%203%205%205%208%204h6v-3c3%203%207%204%2010%202%202%200%204-3%204-5l1-2-1-1c0-3-1-6-3-7-4-2-8-2-11%202v-8h-6zm-47%205h2l-1%201h-3v-1zm80%204v4h-2l1-4zm54%200l1%201v3h-2v-4zm-88%200l1%202-1%203-1-2v-3zm46%200l1%203-1%202c-2%200-2-1-2-2s0-3%202-3zm66%200l2%203-2%202-1-2z%22%20fill%3D%22%23fff%22%20class%3D%22C%22%2F%3E%3Ctext%20x%3D%22489%22%20y%3D%22269.005%22%20xml%3Aspace%3D%22preserve%22%20class%3D%22B%20C%20E%20F%20G%22%3E%3Ctspan%20x%3D%22396.3%22%20y%3D%22288.597%22%3EPas%20de%20correction%3C%2Ftspan%3E%3C%2Ftext%3E%3Cg%20fill%3D%22red%22%20stroke%3D%22red%22%3E%3Cpath%20d%3D%22M472%203.597l74%2080%22%20class%3D%22L%20M%20R%22%2F%3E%3Cpath%20d%3D%22M398%2090.597l78-110%22%20class%3D%22I%20N%22%2F%3E%3C%2Fg%3E%3Cuse%20href%3D%22%23E%22%20fill%3D%22%23fff%22%2F%3E%3Ctext%20x%3D%22619.59%22%20y%3D%22181.15%22%20xml%3Aspace%3D%22preserve%22%20class%3D%22E%20F%20G%20H%22%3E%3Ctspan%20x%3D%22619.59%22%20y%3D%22170.742%22%3EClipping%3C%2Ftspan%3E%3C%2Ftext%3E%3Cuse%20href%3D%22%23E%22%20x%3D%22-137.481%22%20y%3D%22-116.745%22%20fill%3D%22%23fff%22%2F%3E%3Ctext%20x%3D%22482.109%22%20y%3D%2264.405%22%20xml%3Aspace%3D%22preserve%22%20class%3D%22B%20E%20F%20G%22%3E%3Ctspan%20x%3D%22482.109%22%20y%3D%2253.997%22%20fill%3D%22red%22%3EClipping%3C%2Ftspan%3E%3C%2Ftext%3E%3Ctext%20xml%3Aspace%3D%22preserve%22%20x%3D%22157.324%22%20y%3D%22628.32%22%20font-size%3D%2253.513%22%20direction%3D%22ltr%22%20class%3D%22E%20F%20H%20J%22%3E%3Ctspan%20x%3D%22157.324%22%20y%3D%22628.32%22%20stroke%3D%22none%22%20class%3D%22B%22%3ECorrection%20lin%C3%A9aire%3C%2Ftspan%3E%3C%2Ftext%3E%3Ctext%20xml%3Aspace%3D%22preserve%22%20x%3D%22974.709%22%20y%3D%22620.069%22%20font-size%3D%2253.513%22%20direction%3D%22ltr%22%20class%3D%22E%20F%20H%20J%22%3E%3Ctspan%20x%3D%22974.709%22%20y%3D%22620.069%22%20stroke%3D%22none%22%20class%3D%22B%22%3ECorrection%20gamma%3C%2Ftspan%3E%3C%2Ftext%3E%3C%2Fsvg%3E"></center>
#
# Comment pourrait-on calculer ce $\gamma$ à partir de notre facteur d'éclaircissement/assombrissement&nbsp;?
#
# <em>À COMPLÉTER</em>
#
# On peut donc utiliser cette méthode pour modifier la luminosité, en quatre étapes :
# 1) Calcul du $\gamma$ à partir du facteur de luminosité
# 2) Normalisation : $\frac{V_{in}}{255}$
# 3) Application de la puissance gamma : $\left(\frac{V_{in}}{255}\right)^{\gamma}$
# 4) Remise à l'échelle : $255 \times \left(\frac{V_{in}}{255}\right)^{\gamma}$
#
# Essayons pour voir si ça marche mieux. Par contre, faites attention aux types, vous avez des entiers, mais vous allez leur appliquer des divisions, et contrairement aux types classiques de Python, les array NumPy ne se convertissent pas tous seuls à la précision nécessaire pour faire un calcul. Il faudra donc gérer les conversions vous-mêmes. Ceci dit, c'est très facile avec [<code class="language-python">np.<span class="ͼz">astype</span></code>](https://numpy.org/doc/stable//reference/generated/numpy.astype.html).

# %%
matrice = charger("paysage.jpg")

def correction_gamma(matrice, facteur):
    #À COMPLÉTER
    img_ajustee = Image.fromarray(matrice_gamma)
    
    return img_ajustee

facteur = 3 # Augmente la luminosité
resultat = correction_gamma(matrice, facteur)
resultat.show()

# %% [markdown]
# Qu'en pensez-vous&nbsp;? Est-ce mieux que l'ajustement linéaire&nbsp;?

# %% [markdown]
# Voilà&nbsp;! On a déjà implémenté un certain nombre d'opérations de manipulation d'images. Et on a surtout vu à la fin que les traitements avancés utilisent en général une approche assez mathématique des choses...
#
# Maintenant, la suite logique, ce serait pouvoir appliquer ces traitements directement depuis une interface TkInter...
